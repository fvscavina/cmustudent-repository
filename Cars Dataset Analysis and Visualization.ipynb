# %% [markdown]
# # Introduction
# Car Dataset contain nearly about 25000 rows and 9 columns
#
# In this Notebook I am going to analyse and visualize data from Pakistan Used Car data.I have chosen this data because there are no good work on this data and it is good chance to show my little skill on Data Analysis.I hope you will gain some insight from my work.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

cars = pd.read_csv('cars.csv')

# %%
cars
# Out:
#      symboling  normalized-losses         make fueltype aspiration  \
# 0            3                NaN  alfa-romero      gas        std
# 1            3                NaN  alfa-romero      gas        std
# 2            1                NaN  alfa-romero      gas        std
# 3            2              164.0         audi      gas        std
# 4            2              164.0         audi      gas        std
# ..         ...                ...          ...      ...        ...
# 200         -1               95.0        volvo      gas        std
# 201         -1               95.0        volvo      gas      turbo
# 202         -1               95.0        volvo      gas        std
# 203         -1               95.0        volvo   diesel      turbo
# 204         -1               95.0        volvo      gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
cars.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fueltype              object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# enginesize             int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
cars.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  enginesize        bore      stroke  \
# count  205.000000   205.000000  205.000000  201.000000  201.000000
# mean    53.724878  2555.565854  126.907317    3.329751    3.255423
# std      2.443522   520.680204   41.642693    0.273539    0.316717
# ...

# %%
counts = cars['make'].value_counts()
counts
# Out:
# toyota         32
# nissan         18
# mazda          17
# honda          13
# mitsubishi     13
# volkswagen     12
# subaru         12
# peugot         11
# volvo          11
# dodge           9
# bmw             8
# mercedes        8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# alfa-romero     3
# chevrolet       3
# jaguar          3
# renault         2
# mercury         1
# Name: make, dtype: int64

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
counts.plot.bar(ax = ax)
plt.xlabel = ('Maker')
plt.ylabel = ('Number of autos')
plt.title = ('Number of autos by makers')

# %%
cars['fueltype'].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
sns.factorplot('fueltype',data=cars,kind='count')
# Out:
# C:\Users\ferna\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='fueltype', y='price', data=cars, kind='bar')

# %%
var = cars.groupby('make').price.mean()
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.set_xlabel('Brand')
ax1.set_ylabel('Price')
ax1.set_title("Brand Vs Price")
var.plot(kind='bar')

# %%
sns.set_style("whitegrid")
sns.jointplot('horsepower', 'price', data = cars, alpha = 0.3)

# %%
sns.regplot(data = cars,
            x = 'price',
            y = 'horsepower',)

# %%
sns.regplot(data = cars,
            x = 'enginesize',
            y = 'horsepower',)

# %%
plt.figure(figsize = (30,20))
sns.set(style='whitegrid')

plt.subplot(3,1,1)

sns.barplot(data = cars, x = 'make', y = 'price', color = 'green')
                                                    
plt.subplot(3,1,2)
sns.barplot(data = cars, x = 'make', y = 'enginesize', color = 'blue')

plt.subplot(3,1,3)
sns.barplot(data = cars, x = 'make', y = 'horsepower', color = 'red')

# %%
jaguar = cars[cars.make == 'jaguar']
mercedes = cars[cars.make == 'mercedes']
porsche = cars[cars.make == 'porsche']

plt.plot(jaguar.horsepower, jaguar.price)
plt.plot(mercedes.horsepower, mercedes.price)
plt.plot(porsche.horsepower, porsche.price)

plt.legend(['Jaguar', 'Mercedes', 'Porsche'])
plt.title("Horsepower x Price")
plt.show()

# %%
#After visualizing and analysing the data we can say that :

#Most cars are japanese (Toyota, Nissan, Mazda, Honda, Mitsubishi, Subaru)
#Gas cars are the most number of car 
#The average price of diesel cars is higher than that of gas cars
#Jaguar, Mercedes and Porsce are the top 3 most expensive brands
#There is a strong correlation between horsepower and car prices
#There is a strong correlation between horsepower and engine size
#Price, horsepower and engine size are strongly related
#Between the 3 most expensive brands, it's possible to conclude that Porsche has the best cost-benefit ratio, since when comparing it's relationship between prices and horsepower, it shows the best values. In addition, it's possible to conclude that Mercedes has the worst relationship between the big 3.
