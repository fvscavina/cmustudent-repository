# %%
#Patriots Superbowl Experience

"""
Author: Fernando Cavina

"""
#Introduction:

print("""

What\'s up, football fan! Welcome to the Patriots Superbowl Experience!, a 
very simple version that allows you to become the champion of the greatest 
final in the sports world!

In this game, you will have 3 chances to achieve the touchdown and therefore, 
defeat the San Francisco 49ers. During the third play, you have more 3 chances
to score. In case you fail, you will be able to kick the field goal. If it\'s
in, you can try to score the touchdown one more time.

In each step, you must choose a play to make. Among the available moves, 
you have to perform a pass for the Running Back James White; 
or the Wide Receiver Antonio Brown; or the Tight End Rob Gronkowski.

Are you ready to feel like the GOAT Tom Brady!🐐

Let's go to the pitch!

░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
░░░░░░░▄▄▀█▀█▀█▀█▀█▀█▄▄░░░░░░░░░
░░░▄██▀░▄░▄░▄░▄░▄░▄░▄░▀▀██▄░░░░░
░▄▀██░▄████████████████▄░██▀▄░░░
█░░████████████████████████░░█▄░
█░░████████████████████████░░██░
█░░████████████████████████░░█▀░
░▀▄████████████████████████▄▀░░░
░░░▀▀█████████████████████▀░░░░░
░░░░░░░▀▀▀███████████▀▀░░░░░░░░░
░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░   
        
""", end = '') 

input ("<Press enter to start your Superbowl Experience!>\n")

game_name = input("<Choose your game name!>\n")

print(f"\nGreat {game_name} Brady!")

import random
yards = random.randint(6, 14)

def play_1():
    print("\nIt\'s a first try for 10 yards!'\n")
           
    print("Choose who should receive your pass: \n a.James White \n b.Antonio Brown \n c.Rob Gronkowski \nAnswer:")
    choice = input()
         
    if choice == 'a' or choice == 'James White' or choice == 'A':
        print(f"""\nThe running back reached {yards} rushing yards!""")
        
        condition = int(yards)
        while condition < 10 :
            print(f"""\nYou only reached {yards} rushing yards, that\'s not enough. Try again.""")
            play_1()
            
        while condition > 9 :
            play_2()
        
    elif choice == 'b' or choice == 'Antonio Brown' or choice == 'B':
        print("\nFirst down Patriots! Nice pass to Antonio Brown!")
        play_2() # This moves us into play_2
            
    elif choice == 'c' or choice == 'Rob Gronkowski' or choice == 'C':
        print("\nWrong pass from Brady! The Patriots will have to restart from the beggining!")
        play_1() # Brings us back to the beginning of play_1 to try again
        
    else:
        print("\nSomething went wrong. Please, try again. \n")
        play_1() # Brings us back to the beginning of play_1 to try again
          
    
def play_2():
    print("\nGreat decision! You managed to fool the opposing defense and reached important yards!")
    
    print("\nNow it's time to think about your second play!\n")
    
    print("Which play you want to do? \n a.James White \n b.Antonio Brown \n c.Rob Gronkowski \nAnswer: ")
    choice = input()
    
    if choice == 'a' or choice == 'James White' or choice == 'A':
        print("\nAmazing pass!! You are almost there! So close to the Endzone!")
        play_3() # This moves us into play_3

    elif choice == 'b' or choice == 'Antonio Brown' or choice == 'B':
        print("\nIt\'s a fumble!! 49rs got the ball and you lost the game!")
        fail() # This moves us into fail
    
    elif choice == 'c' or choice == 'Rob Gronkowski' or choice == 'C':
        print("\nOoh no Brady! You took too long to pass the ball and got sacked!\n You will have to restart from the beggining")
        play_1() # Brings us back to the beginning of play_1 to try again
        
    else:
        print("\nSomething went wrong. Please, try again. \n")
        play_2() 
             
def play_3():
    print("\nIt\'s 1st and goal! So close to Touchdown!")
    
    chances = 3  
    while chances > 0:
    
        print(f"""\nNumber of chances you have: {chances}""")
        print("\nWho do you think is the right player to score and win the game? \n a.James White \n b.Antonio Brown \n c.Rob Gronkowski \nAnswer: ")
        choice = input("> ")
        chances = chances - 1
        
        # Handling integer cases
        while True:
            
            try:
                choice = str(choice)
                break
            
            except:
                print('You need to use letters only, try again.')
                choice = input("> ")
    
    if choice == 'a' or choice == 'James White' or choice == 'A':
        print("\nGreat performance of 49ers defense this time! White is not going nowhere\n")
        chances = 0
        play_4() 
        
    elif choice == 'b' or choice == 'Antonio Brown' or choice == 'B':
        print("""\nIt\'s TOUCHDOWN for New England!! Congrats, you WON the Suuperbowl!!💍
   _____                       _                   _    _____ _                           
  / ____|                     | |                 | |  / ____| |                          
 | (___  _   _ _ __   ___ _ __| |__   _____      _| | | |    | |__   __ _ _ __ ___  _ __  
  \___ \| | | | '_ \ / _ \ '__| '_ \ / _ \ \ /\ / / | | |    | '_ \ / _` | '_ ` _ \| '_ \ 
  ____) | |_| | |_) |  __/ |  | |_) | (_) \ V  V /| | | |____| | | | (_| | | | | | | |_) |  
 |_____/ \__,_| .__/ \___|_|  |_.__/ \___/ \_/\_/ |_|  \_____|_| |_|\__,_|_| |_| |_| .__/    
              | |                                                                  | |    
              |_|                                                                  |_|         
                                     ___________
                                    '._==_==_=_.'
                                    .-\:      /-.
                                   | (|:.     |) |
                                    '-|:.     |-'
                                      \::.    /
                                       '::. .'
                                         ) (
                                       _.' '._
                                      `"""""""`

""")
        play_5()
        
    elif choice =='c' or choice == 'Rob Gronkowski' or choice == 'C':
        print("\nYou got intercepted by Richard Sherman! What a Cornerback! \n The game is over for you, Brady! \n")
        fail() # This moves us into fail
        
    else:
        print("\nSomething went wrong. Please, try again. \n")
        play_3()
        
def play_4():
    print("\nSince you missed this play, you will have a field goal!\nIf you score, you have another chance to make a touchdown and be the Superbowl champion!\n")   
        
    print("\n<Gostkowski is ready! Press enter to kick the field goal>\n")  
    field = input("<Press enter to kick>\n")
    
    if kick == 1 :
        print("\nAnd Gostkowski GOT IT IN!! You have another chance!\n")
        print("""                  __
               .-'||'-.
             .'   ||   '.
            /   __||__   \
            | /`-    -`\ |
            | | 6    6 | |
            \/\____7___/\/
    .--------:\:I:II:I:/;--------.
   /          \`:I::I:`/          \
  |            `------'            |
  |             \____/             |
  |      ,    __     ___    ,      |
  |======|   /  |   / _ \   |======|
  |======|   ^| |  | | | |  |======|
  |~~~~~|     | |  | |_| |   |~~~~~|
  |     |\   [___]  \___/   /|     |
   \    \|                  |/    /
   `\    \  _ _.-=""=-._ _  /    /'
     `\   '`_)\\-++++-//(_`'   /'
       ;   (__||      ||__)   ;
        ;   ___\      /___   ;
         '. ---/-=..=-\--- .'
           `""`        `""`
""")
        play_1()
        
    elif kick == 2 :
        print("And Gostkowski MISSED IT!!")
        print("\nThe game is over for you and the 49ers are the Superbowl champions!")
        play_5()

import random
kick = random.randint(1, 2)    
            
def play_5():
    print("\nDo you want to play again? \n a.Yes \n b.No \n")
    choice = input()
    if choice == 'a' or choice == 'Yes' or choice == 'Y':
        print("\nBrady is that you?? Always hungry for a ring! Here we go again!")
        play_1() # Brings us back to the beginning of play_1 to try again
        
    else:
        print('\nThanks for playing, Brady! See you next Superbowl! \n')
        exit()
        
def fail():
    #This happens when the player fail the game, so it's over
    
    print("\nEnd of the line for the Patriots! \n Do you want to play again? \n a.Yes \n b.No \n")
    choice = input()
    if choice == 'a' or choice == 'Yes' or choice == 'Y':
        print("\nBrady is that you?? Always hungry for a ring! Here we go again!")
        play_1() # Brings us back to the beginning of play_1 to try again
    
    
    elif choice == 'b' or choice == 'No' or choice == 'N':
        print("\nThanks for playing! See you next Superbowl! \n")
        exit(0)
        
    else:
        print("\nSomething went wrong. Please, try again. \n")
        fail()
        

play_1() # EVERYTHING goes before this clause
# Out:
# What's up, football fan! Welcome to the Patriots Superbowl Experience!, a
# very simple version that allows you to become the champion of the greatest
# final in the sports world!
#
# In this game, you will have 3 chances to achieve the touchdown and therefore,
# defeat the San Francisco 49ers. During the third play, you have more 3 chances
# to score. In case you fail, you will be able to kick the field goal. If it's
# in, you can try to score the touchdown one more time.
#
# In each step, you must choose a play to make. Among the available moves,
# you have to perform a pass for the Running Back James White;
# or the Wide Receiver Antonio Brown; or the Tight End Rob Gronkowski.
#
# Are you ready to feel like the GOAT Tom Brady!🐐
#
# Let's go to the pitch!
#
# ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# ░░░░░░░▄▄▀█▀█▀█▀█▀█▀█▄▄░░░░░░░░░
# ░░░▄██▀░▄░▄░▄░▄░▄░▄░▄░▀▀██▄░░░░░
# ░▄▀██░▄████████████████▄░██▀▄░░░
# █░░████████████████████████░░█▄░
# ...
